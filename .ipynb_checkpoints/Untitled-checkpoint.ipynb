# %%
import googlemaps

# %%
API_key = 'AIzaSyCw2DmHNzB65J0XVTDIRfcW9okQSMYDYFQ'
gmaps = googlemaps.Client(key = API_key)

# %%
import folium

# %%
m = folium.Map(location=[45.5236, -122.6750])
m
# Out:
# <div id="folium_fbc0a3a8ae5d4503a00641f04a6b5715" style="width: 100%; height: 100%"></div>
#
# <script>
#
#   var make_plot = function(){
#     if (typeof L === 'undefined'){
#       window.addEventListener('leaflet_libs_loaded', make_plot)
#       return;
#     }
#
#     var render_plot = (function(){
#
#
#
#       var map = L.map('folium_fbc0a3a8ae5d4503a00641f04a6b5715').setView([45.5236, -122.675], 10);
#
#       L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href="http://openstreetmap.org">OpenStreetMap</a> contributors'
#       }).addTo(map);
#
#
#
#
#
#
#
#
#
#
#
#     })();
#
#   };
#
#   make_plot();
#
# </script>
